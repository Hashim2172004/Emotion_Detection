# %%
# !nvidia-smi
# Out:
# Fri Sep  4 18:02:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d ananthu017/emotion-detection-fer
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/ananthu017/emotion-detection-fer
# License(s): CC0-1.0
# Downloading emotion-detection-fer.zip to /content
# 100% 65.2M/65.2M [00:02<00:00, 25.3MB/s]

# %%
# !unzip -q emotion-detection-fer.zip -d emotion_dataset

# %%
# !find emotion_dataset -maxdepth 2 -type d
# Out:
# emotion_dataset
# emotion_dataset/test
# emotion_dataset/test/happy
# emotion_dataset/test/surprised
# emotion_dataset/test/sad
# emotion_dataset/test/fearful
# emotion_dataset/test/angry
# emotion_dataset/test/neutral
# emotion_dataset/test/disgusted
# emotion_dataset/train
# emotion_dataset/train/happy
# emotion_dataset/train/surprised
# emotion_dataset/train/sad
# emotion_dataset/train/fearful
# emotion_dataset/train/angry
# emotion_dataset/train/neutral
# emotion_dataset/train/disgusted

# %%
import tensorflow as tf

IMG_SIZE = 48
BATCH_SIZE = 64

train_dir = "/content/emotion_dataset/train"
test_dir = "/content/emotion_dataset/test"

train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    shuffle=False
)

print(train_ds.class_names)
# Out:
# Found 28709 files belonging to 7 classes.
# Found 7178 files belonging to 7 classes.
# ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

for images, labels in train_ds.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(images[i].numpy().squeeze(), cmap="gray")
        plt.title(train_ds.class_names[labels[i]])
        plt.axis("off")

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras import layers, models

model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(48, 48, 1)),

    layers.Conv2D(32, (3,3), activation="relu"),
    layers.MaxPooling2D(),

    layers.Conv2D(64, (3,3), activation="relu"),
    layers.MaxPooling2D(),

    layers.Conv2D(128, (3,3), activation="relu"),
    layers.MaxPooling2D(),

    layers.Flatten(),

    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),

    layers.Dense(7, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 355,847 (1.36 MB)
#  Trainable params: 355,847 (1.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=30
)
# Out:
# Epoch 1/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.2835 - loss: 1.7622 - val_accuracy: 0.4090 - val_loss: 1.5692
# Epoch 2/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.4085 - loss: 1.5350 - val_accuracy: 0.4687 - val_loss: 1.4202
# Epoch 3/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.4586 - loss: 1.4149 - val_accuracy: 0.4939 - val_loss: 1.3292
# Epoch 4/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.4912 - loss: 1.3387 - val_accuracy: 0.5128 - val_loss: 1.2766
# Epoch 5/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.5156 - loss: 1.2891 - val_accuracy: 0.5255 - val_loss: 1.2464
# Epoch 6/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.5307 - loss: 1.2410 - val_accuracy: 0.5364 - val_loss: 1.2153
# Epoch 7/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.5499 - loss: 1.2006 - val_accuracy: 0.5341 - val_loss: 1.2037
# Epoch 8/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.5569 - loss: 1.1749 - val_accuracy: 0.5442 - val_loss: 1.1902
# Epoch 9/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.5690 - loss: 1.1379 - val_accuracy: 0.5478 - val_loss: 1.1894
# Epoch 10/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.5819 - loss: 1.1100 - val_accuracy: 0.5545 - val_loss: 1.1812
# Epoch 11/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.5891 - loss: 1.0843 - val_accuracy: 0.5490 - val_loss: 1.1869
# Epoch 12/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6030 - loss: 1.0503 - val_accuracy: 0.5623 - val_loss: 1.1700
# Epoch 13/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.6133 - loss: 1.0180 - val_accuracy: 0.5606 - val_loss: 1.1805
# Epoch 14/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.6246 - loss: 0.9909 - val_accuracy: 0.5667 - val_loss: 1.1769
# Epoch 15/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6370 - loss: 0.9661 - val_accuracy: 0.5568 - val_loss: 1.1891
# Epoch 16/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.6466 - loss: 0.9349 - val_accuracy: 0.5648 - val_loss: 1.2027
# Epoch 17/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.6544 - loss: 0.9154 - val_accuracy: 0.5607 - val_loss: 1.2207
# Epoch 18/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.6638 - loss: 0.8850 - val_accuracy: 0.5660 - val_loss: 1.2258
# Epoch 19/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.6695 - loss: 0.8587 - val_accuracy: 0.5593 - val_loss: 1.2396
# Epoch 20/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.6763 - loss: 0.8421 - val_accuracy: 0.5535 - val_loss: 1.2773
# Epoch 21/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.6857 - loss: 0.8130 - val_accuracy: 0.5609 - val_loss: 1.3091
# Epoch 22/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6928 - loss: 0.7956 - val_accuracy: 0.5554 - val_loss: 1.3157
# Epoch 23/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7020 - loss: 0.7728 - val_accuracy: 0.5596 - val_loss: 1.3231
# Epoch 24/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7112 - loss: 0.7483 - val_accuracy: 0.5563 - val_loss: 1.3883
# Epoch 25/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.7152 - loss: 0.7301 - val_accuracy: 0.5619 - val_loss: 1.3861
# Epoch 26/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7223 - loss: 0.7144 - val_accuracy: 0.5632 - val_loss: 1.4020
# Epoch 27/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.7242 - loss: 0.6985 - val_accuracy: 0.5552 - val_loss: 1.4248
# Epoch 28/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7375 - loss: 0.6777 - val_accuracy: 0.5527 - val_loss: 1.4754
# Epoch 29/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7420 - loss: 0.6533 - val_accuracy: 0.5605 - val_loss: 1.4756
# Epoch 30/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.7448 - loss: 0.6516 - val_accuracy: 0.5499 - val_loss: 1.5688

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model.save("/content/emotion_model.keras")
